# %% [markdown]
# # Imports / Spark Initialization

# %%
# Spark imports
from pyspark.sql import SparkSession
from pyspark.sql.functions import split, when, col

import findspark
from pyspark.sql.types import IntegerType

import random_forest
import pandas as pd
import os
import sys

os.environ['PYSPARK_PYTHON'] = sys.executable
os.environ['PYSPARK_DRIVER_PYTHON'] = sys.executable

findspark.init()


# Initialize a spark session.
def init_spark():
    spark = (
        SparkSession.builder.appName("SOEN 471 Project")
        .config("spark.some.config.option", "some-value")
        .getOrCreate()
    )
    return spark
# %run random_forest.ipynb import randomforest

# %% [markdown]
# # Sample of Initial Data
# Initial row count is of <b>10,003,590</b> values.

# %%
from IPython.display import display

data_dir = os.path.join(os.path.dirname(os.getcwd()), 'data')

spark = init_spark()

df1 = spark.read.csv('male_players.csv', header=True)


players = df1

sample = players.take(5)
sample = pd.DataFrame(sample, columns=sample[0].__fields__)
sample = sample.drop(sample.columns[0], axis=1)

display(sample)
# Out:
#                                  player_url fifa_version fifa_update  \
# 0        /player/158023/lionel-messi/230009           23           9
# 1       /player/165153/karim-benzema/230009           23           9
# 2  /player/188545/robert-lewandowski/230009           23           9
# 3     /player/192985/kevin-de-bruyne/230009           23           9
# 4       /player/231747/kylian-mbappe/230009           23           9
#
#   fifa_update_date      short_name                       long_name  \
# 0       2023-01-13        L. Messi  Lionel Andrés Messi Cuccittini
# 1       2023-01-13      K. Benzema                   Karim Benzema
# 2       2023-01-13  R. Lewandowski              Robert Lewandowski
# 3       2023-01-13    K. De Bruyne                 Kevin De Bruyne
# 4       2023-01-13       K. Mbappé            Kylian Mbappé Lottin
#
#   player_positions overall potential  value_eur  ...   cdm   rdm   rwb    lb  \
# 0               RW      91        91   54000000  ...  63+3  63+3  64+3  59+3
# 1           CF, ST      91        91   64000000  ...  64+3  64+3  64+3  60+3
# 2               ST      91        91   84000000  ...  66+3  66+3  64+3  61+3
# 3          CM, CAM      91        91  107500000  ...  79+3  79+3  78+3  74+3
# 4           ST, LW      91        95  190500000  ...  63+3  63+3  67+3  63+3
#
#     lcb    cb   rcb    rb    gk  \
# 0  50+3  50+3  50+3  59+3  19+3
# 1  55+3  55+3  55+3  60+3  18+3
# 2  60+3  60+3  60+3  61+3  19+3
# 3  68+3  68+3  68+3  74+3  21+3
# 4  54+3  54+3  54+3  63+3  18+3
#
#                                      player_face_url
# 0  https://cdn.sofifa.net/players/158/023/23_120.png
# 1  https://cdn.sofifa.net/players/165/153/23_120.png
# 2  https://cdn.sofifa.net/players/188/545/23_120.png
# 3  https://cdn.sofifa.net/players/192/985/23_120.png
# 4  https://cdn.sofifa.net/players/231/747/23_120.png
#
# [5 rows x 109 columns]

# %% [markdown]
# # Feature Selection
# Selects all field-related features relevant to our model and removes unnecessary characteristics such as player name, height, age, net worth, etc.

# %%
players = players.select(
        "player_positions",
        "overall",
        "skill_moves",
        "pace",
        "shooting",
        "passing",
        "dribbling",
        "defending",
        "physic",
        "attacking_crossing",
        "attacking_finishing",
        "attacking_heading_accuracy",
        "attacking_short_passing",
        "attacking_volleys",
        "skill_dribbling",
        "skill_curve",
        "skill_fk_accuracy",
        "skill_long_passing",
        "skill_ball_control",
        "movement_acceleration",
        "movement_sprint_speed",
        "movement_agility",
        "movement_reactions",
        "movement_balance",
        "power_shot_power",
        "power_jumping",
        "power_stamina",
        "power_strength",
        "power_long_shots",
        "mentality_aggression",
        "mentality_interceptions",
        "mentality_positioning",
        "mentality_vision",
        "mentality_penalties",
        "mentality_composure",
        "defending_marking_awareness",
        "defending_standing_tackle",
        "defending_sliding_tackle",
        "goalkeeping_diving",
        "goalkeeping_handling",
        "goalkeeping_kicking",
        "goalkeeping_positioning",
        "goalkeeping_reflexes",
        "goalkeeping_speed",
    )

sample = players.take(10)
sample = pd.DataFrame(sample, columns=sample[0].__fields__)
display(sample)
# Out:
#   player_positions overall skill_moves  pace shooting passing dribbling  \
# 0               RW      91           4    81       89      90        94
# 1           CF, ST      91           4    80       88      83        87
# 2               ST      91           4    75       91      79        86
# 3          CM, CAM      91           4    74       88      93        87
# 4           ST, LW      91           5    97       89      80        92
# 5               GK      90           1  None     None    None      None
# 6               RW      90           4    90       89      82        90
# 7               GK      89           1  None     None    None      None
# 8               LW      89           5    87       83      85        93
# 9              CDM      89           2    63       73      78        73
#
#   defending physic attacking_crossing  ... mentality_composure  \
# 0        34     64                 84  ...                  96
# 1        39     78                 75  ...                  90
# 2        44     83                 71  ...                  88
# 3        63     77                 94  ...                  89
# 4        36     76                 78  ...                  88
# 5      None   None                 14  ...                  66
# 6        45     75                 80  ...                  92
# 7      None   None                 15  ...                  70
# 8        37     61                 83  ...                  93
# 9        88     89                 62  ...                  84
#
#   defending_marking_awareness defending_standing_tackle  \
# 0                          20                        35
# 1                          43                        24
# 2                          35                        42
# 3                          65                        65
# 4                          26                        34
# 5                          20                        18
# 6                          38                        43
# 7                          17                        10
# 8                          35                        32
# 9                          90                        88
#
#   defending_sliding_tackle goalkeeping_diving goalkeeping_handling  \
# 0                       24                  6                   11
# 1                       18                 13                   11
# 2                       19                 15                    6
# 3                       53                 15                   13
# 4                       32                 13                    5
# 5                       16                 84                   89
# 6                       41                 14                   14
# 7                       11                 87                   88
# 8                       29                  9                    9
# 9                       87                 13                   14
#
#   goalkeeping_kicking goalkeeping_positioning goalkeeping_reflexes  \
# 0                  15                      14                    8
# 1                   5                       5                    7
# 2                  12                       8                   10
# 3                   5                      10                   13
# 4                   7                      11                    6
# 5                  75                      89                   90
# 6                   9                      11                   14
# 7                  90                      88                   87
# 8                  15                      15                   11
# 9                  16                      12                   12
#
#   goalkeeping_speed
# 0              None
# 1              None
# 2              None
# 3              None
# 4              None
# 5                46
# 6              None
# 7                49
# 8              None
# 9              None
#
# [10 rows x 44 columns]

# %% [markdown]
# As seen above, most players have more than one preferred position, displayed in increasing order. We therefore filter through the positions and return only the most preferred, creating a new column and dropping the previous one.

# %%
players = players.withColumn(
        "player_position", split(players["player_positions"], ",")[0]
    ).drop("player_positions")

sample = players.select(players.columns[-1]).take(10)
sample = pd.DataFrame(sample, columns=sample[0].__fields__)
display(sample)
# Out:
#   player_position
# 0              RW
# 1              CF
# 2              ST
# 3              CM
# 4              ST
# 5              GK
# 6              RW
# 7              GK
# 8              LW
# 9             CDM

# %% [markdown]
# For players whose position is goalkeeper, important attribute fields are empty, such as shooting, passing, dribbling, defending, etc. We therefore remove all goal-keeping related attributes and goal-keepers from our data selection.
#
# Reduces our row count from <b>10,003,590</b> to <b>8,882,644</b>.

# %%
players = players.drop(
        "goalkeeping_diving",
        "goalkeeping_handling",
        "goalkeeping_kicking",
        "goalkeeping_positioning",
        "goalkeeping_reflexes",
        "goalkeeping_speed",
    ).filter(players.player_position != "GK")

sample = players.take(10)
sample = pd.DataFrame(sample, columns=sample[0].__fields__)
display(sample)
# Out:
#   overall skill_moves pace shooting passing dribbling defending physic  \
# 0      91           4   81       89      90        94        34     64
# 1      91           4   80       88      83        87        39     78
# 2      91           4   75       91      79        86        44     83
# 3      91           4   74       88      93        87        63     77
# 4      91           5   97       89      80        92        36     76
# 5      90           4   90       89      82        90        45     75
# 6      89           5   87       83      85        93        37     61
# 7      89           2   63       73      78        73        88     89
# 8      89           3   69       91      83        83        47     82
# 9      89           2   81       60      71        72        90     86
#
#   attacking_crossing attacking_finishing  ... mentality_aggression  \
# 0                 84                  90  ...                   44
# 1                 75                  92  ...                   63
# 2                 71                  94  ...                   81
# 3                 94                  85  ...                   75
# 4                 78                  93  ...                   64
# 5                 80                  93  ...                   63
# 6                 83                  83  ...                   63
# 7                 62                  64  ...                   91
# 8                 80                  93  ...                   80
# 9                 53                  52  ...                   85
#
#   mentality_interceptions mentality_positioning mentality_vision  \
# 0                      40                    93               94
# 1                      39                    92               89
# 2                      49                    94               81
# 3                      64                    88               94
# 4                      38                    92               83
# 5                      55                    92               85
# 6                      37                    86               90
# 7                      88                    75               79
# 8                      44                    94               87
# 9                      89                    47               65
#
#   mentality_penalties mentality_composure defending_marking_awareness  \
# 0                  75                  96                          20
# 1                  84                  90                          43
# 2                  90                  88                          35
# 3                  83                  89                          65
# 4                  80                  88                          26
# 5                  86                  92                          38
# 6                  91                  93                          35
# 7                  66                  84                          90
# 8                  92                  92                          50
# 9                  62                  90                          91
#
#   defending_standing_tackle defending_sliding_tackle player_position
# 0                        35                       24              RW
# 1                        24                       18              CF
# 2                        42                       19              ST
# 3                        65                       53              CM
# 4                        34                       32              ST
# 5                        43                       41              RW
# 6                        32                       29              LW
# 7                        88                       87             CDM
# 8                        36                       38              ST
# 9                        91                       86              CB
#
# [10 rows x 38 columns]

# %% [markdown]
# We then drop features which are not discriminative towards any of the labels, and where same values can easily be obtained between players of all classes.

# %%
players = players.drop(
        "overall",
        "skill_moves",
        "physic",
        "skill_curve",
        "movement_reactions",
        "power_jumping",
        "power_strength",
        "mentality_aggression",
        "mentality_vision",
        "mentality_composure",
    )

sample = players.take(5)
sample = pd.DataFrame(sample, columns=sample[0].__fields__)
display(sample)
# Out:
#   pace shooting passing dribbling defending attacking_crossing  \
# 0   81       89      90        94        34                 84
# 1   80       88      83        87        39                 75
# 2   75       91      79        86        44                 71
# 3   74       88      93        87        63                 94
# 4   97       89      80        92        36                 78
#
#   attacking_finishing attacking_heading_accuracy attacking_short_passing  \
# 0                  90                         70                      91
# 1                  92                         90                      89
# 2                  94                         91                      84
# 3                  85                         55                      93
# 4                  93                         72                      85
#
#   attacking_volleys  ... power_shot_power power_stamina power_long_shots  \
# 0                88  ...               86            70               91
# 1                88  ...               87            82               80
# 2                89  ...               91            76               84
# 3                83  ...               92            89               91
# 4                83  ...               88            87               82
#
#   mentality_interceptions mentality_positioning mentality_penalties  \
# 0                      40                    93                  75
# 1                      39                    92                  84
# 2                      49                    94                  90
# 3                      64                    88                  83
# 4                      38                    92                  80
#
#   defending_marking_awareness defending_standing_tackle  \
# 0                          20                        35
# 1                          43                        24
# 2                          35                        42
# 3                          65                        65
# 4                          26                        34
#
#   defending_sliding_tackle player_position
# 0                       24              RW
# 1                       18              CF
# 2                       19              ST
# 3                       53              CM
# 4                       32              ST
#
# [5 rows x 28 columns]

# %% [markdown]
# # Label Conversion
# Converts FIFA-defined positions to one of our three labels:

# %%
def label_conversion(player_position):
    player_position = (
        when(player_position.isin(["CB", "RB", "LB", "RWB", "LWB"]), "Defender")
        .when(player_position.isin(["CM", "CDM", "CAM", "RM", "LM"]), "Midfielder")
        .when(player_position.isin(["ST", "CF", "RF", "LF", "RW", "LW"]), "Forward")
        .otherwise("Undefined")
    )

    return player_position

# %% [markdown]
# Converts specific positions such as RW, CDM, LB to a more general label (defender, midfielder or forward):

# %%
players = players.withColumn(
        "label_position", label_conversion(players["player_position"])
    ).drop("player_position")

sample = players.select(players.columns[-1]).take(10)
sample = pd.DataFrame(sample, columns=sample[0].__fields__)
display(sample)
# Out:
#   label_position
# 0        Forward
# 1        Forward
# 2        Forward
# 3     Midfielder
# 4        Forward
# 5        Forward
# 6        Forward
# 7     Midfielder
# 8        Forward
# 9       Defender

# %% [markdown]
# We complete the data preparation phase by dropping rows containing null values or a label position of "Undefined". No undefined positions were counted but removing nulls minimally reduces our row count from <b>8,882,644</b> to <b>8,882,438</b>.

# %%
players.filter(players.label_position != "Undefined")
players = players.dropna()

# %% [markdown]
# Final sample of features (total counts <b>3,266,866</b> Defenders, <b>3,712,577</b> Midfielders, and <b>1,902,995</b> Forwards):

# %%
for col_name in players.columns:
        if col_name != "label_position":
            players = players.withColumn(col_name, col(col_name).cast(IntegerType()))

sample = players.take(10)
sample = pd.DataFrame(sample, columns=sample[0].__fields__)
display(sample)
# Out:
#    pace  shooting  passing  dribbling  defending  attacking_crossing  \
# 0    81        89       90         94         34                  84
# 1    80        88       83         87         39                  75
# 2    75        91       79         86         44                  71
# 3    74        88       93         87         63                  94
# 4    97        89       80         92         36                  78
# 5    90        89       82         90         45                  80
# 6    87        83       85         93         37                  83
# 7    63        73       78         73         88                  62
# 8    69        91       83         83         47                  80
# 9    81        60       71         72         90                  53
#
#    attacking_finishing  attacking_heading_accuracy  attacking_short_passing  \
# 0                   90                          70                       91
# 1                   92                          90                       89
# 2                   94                          91                       84
# 3                   85                          55                       93
# 4                   93                          72                       85
# 5                   93                          59                       84
# 6                   83                          63                       85
# 7                   64                          81                       84
# 8                   93                          85                       84
# 9                   52                          86                       79
#
#    attacking_volleys  ...  power_shot_power  power_stamina  power_long_shots  \
# 0                 88  ...                86             70                91
# 1                 88  ...                87             82                80
# 2                 89  ...                91             76                84
# 3                 83  ...                92             89                91
# 4                 83  ...                88             87                82
# 5                 84  ...                83             87                85
# 6                 86  ...                79             79                81
# 7                 65  ...                88             88                81
# 8                 87  ...                92             83                86
# 9                 45  ...                81             74                64
#
#    mentality_interceptions  mentality_positioning  mentality_penalties  \
# 0                       40                     93                   75
# 1                       39                     92                   84
# 2                       49                     94                   90
# 3                       64                     88                   83
# 4                       38                     92                   80
# 5                       55                     92                   86
# 6                       37                     86                   91
# 7                       88                     75                   66
# 8                       44                     94                   92
# 9                       89                     47                   62
#
#    defending_marking_awareness  defending_standing_tackle  \
# 0                           20                         35
# 1                           43                         24
# 2                           35                         42
# 3                           65                         65
# 4                           26                         34
# 5                           38                         43
# 6                           35                         32
# 7                           90                         88
# 8                           50                         36
# 9                           91                         91
#
#    defending_sliding_tackle  label_position
# 0                        24         Forward
# 1                        18         Forward
# 2                        19         Forward
# 3                        53      Midfielder
# 4                        32         Forward
# 5                        41         Forward
# 6                        29         Forward
# 7                        87      Midfielder
# 8                        38         Forward
# 9                        86        Defender
#
# [10 rows x 28 columns]

# %% [markdown]
# # Data Sampling
# As an attempt to improve results, we undersample the data to reduce class imbalance, returning 1,500,000 player values for each of the three classes (also easily splittable into two thirds training and one third testing).

# %%
defenders = players.filter(players.label_position == "Defender")
midfielders = players.filter(players.label_position == "Midfielder")
forwards = players.filter(players.label_position == "Forward")

# %%
defenders = defenders.sample(fraction=1500000 / defenders.count()).limit(1500000)
midfielders = midfielders.sample(fraction=1500000 / midfielders.count()).limit(1500000)
forwards = forwards.sample(fraction=1500000 / forwards.count()).limit(1500000)

sampled_players = defenders.union(midfielders).union(forwards)

print("Defenders: {}".format(defenders.count()))
print("Midfielders: {}".format(midfielders.count()))
print("Forwards: {}".format(forwards.count()))
print("Total number of sampled players: {}".format(sampled_players.count()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 defenders = defenders.sample(fraction=1500000 / defenders.count()).limit(1500000)
#       2 midfielders = midfielders.sample(fraction=1500000 / midfielders.count()).limit(1500000)
#       3 forwards = forwards.sample(fraction=1500000 / forwards.count()).limit(1500000)
#
# NameError: name 'defenders' is not defined

# %%
df = sampled_players

# %%
randomforest(df)
# Out:
# C:\Users\Admin\anaconda3\envs\soen471\Lib\site-packages\pyspark\sql\context.py:125: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   warnings.warn(
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\envs\soen471\Lib\site-packages\pyspark\serializers.py", line 437, in dumps
#     return cloudpickle.dumps(obj, pickle_protocol)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\envs\soen471\Lib\site-packages\pyspark\cloudpickle\cloudpickle_fast.py", line 73, in dumps
#     cp.dump(obj)
#   File "C:\Users\Admin\anaconda3\envs\soen471\Lib\site-packages\pyspark\cloudpickle\cloudpickle_fast.py", line 563, in dump
#     return Pickler.dump(self, obj)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\envs\soen471\Lib\site-packages\pyspark\cloudpickle\cloudpickle_fast.py", line 653, in reducer_override
#     return self._function_reduce(obj)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\envs\soen471\Lib\site-packages\pyspark\cloudpickle\cloudpickle_fast.py", line 526, in _function_reduce
#     return self._dynamic_function_reduce(obj)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\envs\soen471\Lib\site-packages\pyspark\cloudpickle\cloudpickle_fast.py", line 507, in _dynamic_function_reduce
#     state = _function_getstate(func)
#             ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\envs\soen471\Lib\site-packages\pyspark\cloudpickle\cloudpickle_fast.py", line 157, in _function_getstate
#     f_globals_ref = _extract_code_globals(func.__code__)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\envs\soen471\Lib\site-packages\pyspark\cloudpickle\cloudpickle.py", line 236, in _extract_code_globals
#     out_names = {names[oparg] for _, oparg in _walk_global_ops(co)}
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\envs\soen471\Lib\site-packages\pyspark\cloudpickle\cloudpickle.py", line 236, in <setcomp>
#     out_names = {names[oparg] for _, oparg in _walk_global_ops(co)}
#                  ~~~~~^^^^^^^
# IndexError: tuple index out of range
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~\anaconda3\envs\soen471\Lib\site-packages\pyspark\serializers.py:437, in CloudPickleSerializer.dumps(self, obj)
#     436 try:
# --> 437     return cloudpickle.dumps(obj, pickle_protocol)
#     438 except pickle.PickleError:
#
# File ~\anaconda3\envs\soen471\Lib\site-packages\pyspark\cloudpickle\cloudpickle_fast.py:73, in dumps(obj, protocol, buffer_callback)
#      70 cp = CloudPickler(
#      71     file, protocol=protocol, buffer_callback=buffer_callback
#      72 )
# ---> 73 cp.dump(obj)
#      74 return file.getvalue()
#
# File ~\anaconda3\envs\soen471\Lib\site-packages\pyspark\cloudpickle\cloudpickle_fast.py:563, in CloudPickler.dump(self, obj)
#     562 try:
# --> 563     return Pickler.dump(self, obj)
#     564 except RuntimeError as e:
#
# File ~\anaconda3\envs\soen471\Lib\site-packages\pyspark\cloudpickle\cloudpickle_fast.py:653, in CloudPickler.reducer_override(self, obj)
#     652 elif isinstance(obj, types.FunctionType):
# --> 653     return self._function_reduce(obj)
#     654 else:
#     655     # fallback to save_global, including the Pickler's
#     656     # distpatch_table
#
# File ~\anaconda3\envs\soen471\Lib\site-packages\pyspark\cloudpickle\cloudpickle_fast.py:526, in CloudPickler._function_reduce(self, obj)
#     525 else:
# --> 526     return self._dynamic_function_reduce(obj)
#
# File ~\anaconda3\envs\soen471\Lib\site-packages\pyspark\cloudpickle\cloudpickle_fast.py:507, in CloudPickler._dynamic_function_reduce(self, func)
#     506 newargs = self._function_getnewargs(func)
# --> 507 state = _function_getstate(func)
#     508 return (types.FunctionType, newargs, state, None, None,
#     509         _function_setstate)
#
# File ~\anaconda3\envs\soen471\Lib\site-packages\pyspark\cloudpickle\cloudpickle_fast.py:157, in _function_getstate(func)
#     146 slotstate = {
#     147     "__name__": func.__name__,
#     148     "__qualname__": func.__qualname__,
#    (...)
#     154     "__closure__": func.__closure__,
#     155 }
# --> 157 f_globals_ref = _extract_code_globals(func.__code__)
#     158 f_globals = {k: func.__globals__[k] for k in f_globals_ref if k in
#     159              func.__globals__}
#
# File ~\anaconda3\envs\soen471\Lib\site-packages\pyspark\cloudpickle\cloudpickle.py:236, in _extract_code_globals(co)
#     235 names = co.co_names
# --> 236 out_names = {names[oparg] for _, oparg in _walk_global_ops(co)}
#     238 # Declaring a function inside another one using the "def ..."
#     239 # syntax generates a constant code object corresonding to the one
#     240 # of the nested function's As the nested function may itself need
#     241 # global variables, we need to introspect its code, extract its
#     242 # globals, (look for code object in it's co_consts attribute..) and
#     243 # add the result to code_globals
#
# File ~\anaconda3\envs\soen471\Lib\site-packages\pyspark\cloudpickle\cloudpickle.py:236, in <setcomp>(.0)
#     235 names = co.co_names
# --> 236 out_names = {names[oparg] for _, oparg in _walk_global_ops(co)}
#     238 # Declaring a function inside another one using the "def ..."
#     239 # syntax generates a constant code object corresonding to the one
#     240 # of the nested function's As the nested function may itself need
#     241 # global variables, we need to introspect its code, extract its
#     242 # globals, (look for code object in it's co_consts attribute..) and
#     243 # add the result to code_globals
#
# IndexError: tuple index out of range
#
# During handling of the above exception, another exception occurred:
#
# PicklingError                             Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 randomforest(df)
#
# File ~\AppData\Local\Temp\ipykernel_17588\3302390919.py:24, in randomforest(df)
#      21 predictions_and_labels_pd= predictions.select("prediction", "label_position_index").toPandas()
#      23 # Generate confusion matrix
# ---> 24 metrics = MulticlassMetrics(predictions_and_labels)
#      25 confusion_matrix = metrics.confusionMatrix().toArray()
#      27 # Generate classification report
#
# File ~\anaconda3\envs\soen471\Lib\site-packages\pyspark\mllib\evaluation.py:270, in MulticlassMetrics.__init__(self, predictionAndLabels)
#     268 sc = predictionAndLabels.ctx
#     269 sql_ctx = SQLContext.getOrCreate(sc)
# --> 270 numCol = len(predictionAndLabels.first())
#     271 schema = StructType([
#     272     StructField("prediction", DoubleType(), nullable=False),
#     273     StructField("label", DoubleType(), nullable=False)])
#     274 if numCol >= 3:
#
# File ~\anaconda3\envs\soen471\Lib\site-packages\pyspark\rdd.py:1588, in RDD.first(self)
#    1575 def first(self):
#    1576     """
#    1577     Return the first element in this RDD.
#    1578
#    (...)
#    1586     ValueError: RDD is empty
#    1587     """
# -> 1588     rs = self.take(1)
#    1589     if rs:
#    1590         return rs[0]
#
# File ~\anaconda3\envs\soen471\Lib\site-packages\pyspark\rdd.py:1568, in RDD.take(self, num)
#    1565         taken += 1
#    1567 p = range(partsScanned, min(partsScanned + numPartsToTry, totalParts))
# -> 1568 res = self.context.runJob(self, takeUpToNumLeft, p)
#    1570 items += res
#    1571 partsScanned += numPartsToTry
#
# File ~\anaconda3\envs\soen471\Lib\site-packages\pyspark\context.py:1227, in SparkContext.runJob(self, rdd, partitionFunc, partitions, allowLocal)
#    1223 # Implementation note: This is implemented as a mapPartitions followed
#    1224 # by runJob() in order to avoid having to pass a Python lambda into
#    1225 # SparkContext#runJob.
#    1226 mappedRDD = rdd.mapPartitions(partitionFunc)
# -> 1227 sock_info = self._jvm.PythonRDD.runJob(self._jsc.sc(), mappedRDD._jrdd, partitions)
#    1228 return list(_load_from_socket(sock_info, mappedRDD._jrdd_deserializer))
#
# File ~\anaconda3\envs\soen471\Lib\site-packages\pyspark\rdd.py:2951, in PipelinedRDD._jrdd(self)
#    2948 else:
#    2949     profiler = None
# -> 2951 wrapped_func = _wrap_function(self.ctx, self.func, self._prev_jrdd_deserializer,
#    2952                               self._jrdd_deserializer, profiler)
#    2953 python_rdd = self.ctx._jvm.PythonRDD(self._prev_jrdd.rdd(), wrapped_func,
#    2954                                      self.preservesPartitioning, self.is_barrier)
#    2955 self._jrdd_val = python_rdd.asJavaRDD()
#
# File ~\anaconda3\envs\soen471\Lib\site-packages\pyspark\rdd.py:2830, in _wrap_function(sc, func, deserializer, serializer, profiler)
#    2828 assert serializer, "serializer should not be empty"
#    2829 command = (func, profiler, deserializer, serializer)
# -> 2830 pickled_command, broadcast_vars, env, includes = _prepare_for_python_RDD(sc, command)
#    2831 return sc._jvm.PythonFunction(bytearray(pickled_command), env, includes, sc.pythonExec,
#    2832                               sc.pythonVer, broadcast_vars, sc._javaAccumulator)
#
# File ~\anaconda3\envs\soen471\Lib\site-packages\pyspark\rdd.py:2816, in _prepare_for_python_RDD(sc, command)
#    2813 def _prepare_for_python_RDD(sc, command):
#    2814     # the serialized command will be compressed by broadcast
#    2815     ser = CloudPickleSerializer()
# -> 2816     pickled_command = ser.dumps(command)
#    2817     if len(pickled_command) > sc._jvm.PythonUtils.getBroadcastThreshold(sc._jsc):  # Default 1M
#    2818         # The broadcast will have same life cycle as created PythonRDD
#    2819         broadcast = sc.broadcast(pickled_command)
#
# File ~\anaconda3\envs\soen471\Lib\site-packages\pyspark\serializers.py:447, in CloudPickleSerializer.dumps(self, obj)
#     445     msg = "Could not serialize object: %s: %s" % (e.__class__.__name__, emsg)
#     446 print_exec(sys.stderr)
# --> 447 raise pickle.PicklingError(msg)
#
# PicklingError: Could not serialize object: IndexError: tuple index out of range
